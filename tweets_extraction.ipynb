# %% [markdown]
# ![title](./logo_nao_digital.png)

# %% [markdown]
# # MySQL-SQL Server en la Gestión de Bases de Datos Relacionales

# %% [markdown]
# ## Evidencias Ciclo 1

# %% [markdown]
# *Instrucciones:*
#
#
# Atiende las siguientes indicaciones para completar las evidencias de este primer ciclo de investigación y desarrollo de esta experiencia de aprendizaje.
#
# 1. Lee detenidamente el reto MySQL/SQL Server en la gestión de bases de datos relacionales
#
# 2. Desarrolla las evidencias solicitadas para este ciclo ID:
# * Utiliza código Python en GitHub para:
#     * Extraer tweets
#     * Verificar tipos de datos.
#
# 3. Sube las evidencias a tu espacio en Notion.

# %% [markdown]
# ## Etapa 1: instalar e importar librerías de trabajo

# %%
# %pip install pandas
import pandas as pd
import json
import re

from datetime import datetime
from collections import Counter
# Out:
# Requirement already satisfied: pandas in c:\users\natalia\anaconda3\lib\site-packages (2.0.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\natalia\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\natalia\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\natalia\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\natalia\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\natalia\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Etapa 2: Extraer tweets

# %%
# Leer el archivo JSON
with open('tweets_extraction.json', 'r', encoding = 'utf-8') as file:
    tweets_extraction = json.load(file)

# %%
tweets_extraction
# Out:
# [{'id': '12116719578733158',
#   'texto': '#BrechaAnuario2019 | Con cañón y coronel El voto a Cabildo Abierto en la periferia de Montevideo. por Venancio Acosta https://brecha.com.uy/con-canon-y-coronel-2/… #RelecturasDeUnAñoPerturbador',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['BrechaAnuario2019', 'RelecturasDeUnAñoPerturbador'],
#   'fecha': '2021-12-30T15:34:41.000Z',
#   'retweets': 3.0,
#   'favoritos': 2.0},
#  {'id': '12116547084876964',
#   'texto': '#BrechaAnuario2019 | Las PASO en Argentina "Empezamos a ver, después de unos años catastróficos para la izquierda sudamericana, que es posible montar defensas, contraataques, replanteos estratégicos, nuevas alianzas, actores y lenguajes." por @dedelacoste  https://brecha.com.uy/vamos-a-volver-2/…',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['BrechaAnuario2019'],
#   'fecha': '2021-12-30T14:26:08.000Z',
#   'retweets': 2.0,
#   'favoritos': 1.0},
#  {'id': '12116529643744993',
#   'texto': '#BrechaAnuario2019 | Bolsonaro contra la selva amazónica En plena cruzada para aumentar su frontera agrícola y minera, Brasil arde con más de mil incendios por día. por Marcelo Aguilar https://brecha.com.uy/corte-raso-2/',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['BrechaAnuario2019'],
#   'fecha': '2021-12-30T14:19:12.000Z',
#   'retweets': 3.0,
#   'favoritos': 2.0},
#  {'id': '12110290516301292',
#   'texto': '#BrechaAnuario2019 | Aquí, los temas que aparecieron este año y también aquellos que se repiten a lo largo del tiempo y permiten al lector consecuente del semanario trazar continuidades que ayudan al análisis y a la comprensión global de los asuntos. #RelecturasDeUnAñoPerturbador GIF',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['BrechaAnuario2019', 'RelecturasDeUnAñoPerturbador'],
#   'fecha': '2021-12-28T21:00:00.000Z',
#   'retweets': 2.0,
#   'favoritos': 5.0},
#  {'id': '12107119614801142',
#   'texto': '#BrechaAnuario2019 | El mejor dibujante de historietas argentino fue un uruguayo. Alberto Breccia nació en Montevideo en 1919, pero a los 3 años ya residía en Buenos Aires. por María José Santacreu https://brecha.com.uy/el-viejo-3/',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['BrechaAnuario2019'],
#   'fecha': '2021-12-28T00:00:00.000Z',
#   'retweets': 0.0,
#   'favoritos': 4.0},
#  {'id': '1210681764626092',
#   'texto': '#BrechaAnuario2019 | Rock’n Rimbaud En noviembre, Patti Smith desembarcó en Montevideo. Una buena oportunidad para repasar sus comienzos en la música y la literatura. por María José Santacreu https://brecha.com.uy/rockn-rimbaud-2/…',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['BrechaAnuario2019'],
#   'fecha': '2021-12-27T22:00:00.000Z',
#   'retweets': 2.0,
#   'favoritos':
…',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': [],
#   'fecha': '2021-12-06T13:10:52.000Z',
#   'retweets': 3.0,
#   'favoritos': 2.0},
#  {'id': '120293760809719',
#   'texto': 'Además, el futuro secretario de la Presidencia evaluó la buena votación del Frente Amplio en noviembre, dio su parecer sobre el rol de Cabildo Abierto de cara a un gobierno de coalición y confirmó la continuidad del contrato con Upm.',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': [],
#   'fecha': '2021-12-06T13:07:29.000Z',
#   'retweets': 0.0,
#   'favoritos': 0.0},
#  {'id': '12029370961991352',
#   'texto': 'Delgado también aseguró a  @SemanarioBrecha  que el Partido Nacional acompañará a Manini en su voluntad de no ampararse en los fueros parlamentarios para evitar un proceso judicial.',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': [],
#   'fecha': '2021-12-06T13:05:27.000Z',
#   'retweets': 1.0,
#   'favoritos': 1.0},
#  {'id': '12029358979368468',
#   'texto': 'A su juicio, es posible dinamizar la economía mientras se procesa el ajuste fiscal. “Son 900 millones de dólares de ahorro el primer año, que se irán incrementando a lo largo del período”.',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': [],
#   'fecha': '2021-12-06T13:00:42.000Z',
#   'retweets': 0.0,
#   'favoritos': 0.0},
#  {'id': '1202935531795034',
#   'texto': 'Delgado afirmó que los consejos de salarios no se eliminarán, pero sí se reformarán y se prohibirán las ocupaciones.',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': [],
#   'fecha': '2021-12-06T12:59:14.000Z',
#   'retweets': 0.0,
#   'favoritos': 0.0},
#  {'id': '12029349641925304',
#   'texto': '“Hablarles a los nuestros y a los ajenos” | Con Álvaro Delgado, próximo secretario de Presidencia  por  @_quemeimporta_  y @dedelacoste  foto: Héctor Piastri https://brecha.com.uy/hablarles-a-los-nuestros-y-a-los-ajenos/…',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': [],
#   'fecha': '2021-12-06T12:56:59.000Z',
#   'retweets': 2.0,
#   'favoritos': 2.0},
#  {'id': '12029254040944353',
#   'texto': 'Hasta el 30 de noviembre fueron 19 las víctimas de femicidios en nuestro país en 2019. Declaramos duelo nacional para reflexionar sobre lo que no debió pasar. Ellas deberían estar vivas. #DueloNacional',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['DueloNacional'],
#   'fecha': '2021-12-06T12:19:00.000Z',
#   'retweets': 6.0,
#   'favoritos': 14.0},
#  {'id': '1202895456662983',
#   'texto': 'Nuestra #tapa de la semana:  • ‘Tamos como queremos | Con Álvaro Delgado, próximo secretario de la Presidencia • El PERI, un partido verde en el Parlamento • Represión y proceso constituyente en Chile • Cianobacterias: el turismo sufriendo el agro  (foto: Héctor Piastri)',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['tapa'],
#   'fecha': '2021-12-06T10:20:00.000Z',
#   'retweets': 4.0,
#   'favoritos': 8.0},
#  {'id': '12027493361967022',
#   'texto': 'Adelanto | Este viernes en la apertura de #Política:',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['Política'],
#   'fecha': '2021-12-06T00:39:22.000Z',
#   'retweets': 1.0,
#   'favoritos': 4.0},
#  {'id': '12027416793520947',
#   'texto': 'Adelanto | Este viernes, en nuestra apertura de #Cultura:',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['Cultura'],
#   'fecha': '2021-12-06T00:08:56.000Z',
#   'retweets': 3.0,
#   'favoritos': 3.0},
#  {'id': '12027176696796815',
#   'texto': 'Adelanto | Este viernes, en nuestra apertura de #Sociedad: Cianobacterias y turismo.  Informe de  @taniaferre1ra',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['Sociedad'],
#   'fecha': '2021-12-05T22:33:32.000Z',
#   'retweets': 6.0,
#   'favoritos': 14.0},
#  {'id': '12016057081496453',
#   'texto': 'Opinión | Botín de guerra y excusa ¿Sobre qué modelo económico se sustentan las políticas redistributivas y antirracistas en Bolivia? por Luis Martín-Cabrera, director del Programa de Estudios Latinoamericanos de la Universidad de California en San Diego. https://brecha.com.uy/botin-de-guerra-y-excusa/…',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': [],
#   'fecha': '2021-12

#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['portada', 'Informe'],
#   'fecha': '2021-05-31T13:14:34.000Z',
#   'retweets': 3.0,
#   'favoritos': 2.0},
#  {'id': '113427123619908',
#   'texto': 'ADELANTO | Mañana en #Sociedad: La denuncia de acoso sexual y laboral de Jana Rodríguez Hertz y su escenario.',
#   'usuario': 'SemanarioBrecha',
#   'hashtags': ['Sociedad'],
#   'fecha': '2021-05-31T01:31:51.000Z',
#   'retweets': 2.0,
#   'favoritos': 8.0},
#  ...]

# %% [markdown]
# ## Etapa 3: Identificar tipos de datos

# %%
# Validación de Datos
# Asumiendo que cada tweet tiene los campos id, texto, usuario, hashtags, fecha, retweets, favoritos
for tweet in tweets_extraction:
    assert all(key in tweet for key in ['id', 'texto', 'usuario', 'hashtags', 'fecha', 'retweets', 'favoritos'])

# %% [markdown]
# Esta parte del código asegura que cada tweet en la lista data tenga todos los campos esenciales necesarios.

# %%
# Obtener un elemento representativo para análisis
primer_elemento = tweets_extraction[0] if isinstance(tweets_extraction, list) and tweets_extraction else tweets_extraction

# Función para explorar tipos de datos
def explore_data(tweets_extraction, path=''):
    if type(tweets_extraction) == dict:
        for key, value in tweets_extraction.items():
            explore_data(value, path + f'/{key}')
    elif type(tweets_extraction) == list:
        for i, item in enumerate(tweets_extraction):
            explore_data(item, path + f'[{i}]')
    else:
        print(f"{path}: {type(tweets_extraction)}")

# Llama a la función para explorar los tipos de datos usando el primer elemento
explore_data(primer_elemento)
# Out:
# /id: <class 'str'>
# /texto: <class 'str'>
# /usuario: <class 'str'>
# /hashtags[0]: <class 'str'>
# /hashtags[1]: <class 'str'>
# /fecha: <class 'str'>
# /retweets: <class 'float'>
# /favoritos: <class 'float'>

# %%
# Convertir tipos de datos
for tweet in tweets_extraction:
    # Convertir la fecha de string a formato YYYY-MM-DD
    tweet['fecha'] = datetime.strptime(tweet['fecha'], '%Y-%m-%dT%H:%M:%S.%fZ')

    # Convertir retweets y favoritos de float a int
    tweet['retweets'] = int(tweet['retweets'])
    tweet['favoritos'] = int(tweet['favoritos'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Natalia\Recursos DN_COM_58\DIGITAL-NAO-RETO_3-MySQL-SQL_SERVER_EN_LA_GESTIÓN_DE_BASES_DE_DATOS_RELACIONALES\tweets_extraction.ipynb Cell 14 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Natalia/Recursos%20DN_COM_58/DIGITAL-NAO-RETO_3-MySQL-SQL_SERVER_EN_LA_GESTI%C3%93N_DE_BASES_DE_DATOS_RELACIONALES/tweets_extraction.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> # Convertir tipos de datos
#       <a href='vscode-notebook-cell:/c%3A/Users/Natalia/Recursos%20DN_COM_58/DIGITAL-NAO-RETO_3-MySQL-SQL_SERVER_EN_LA_GESTI%C3%93N_DE_BASES_DE_DATOS_RELACIONALES/tweets_extraction.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> for tweet in tweets_extraction:
#       <a href='vscode-notebook-cell:/c%3A/Users/Natalia/Recursos%20DN_COM_58/DIGITAL-NAO-RETO_3-MySQL-SQL_SERVER_EN_LA_GESTI%C3%93N_DE_BASES_DE_DATOS_RELACIONALES/tweets_extraction.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a>     # Convertir la fecha de string a formato YYYY-MM-DD
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Natalia/Recursos%20DN_COM_58/DIGITAL-NAO-RETO_3-MySQL-SQL_SERVER_EN_LA_GESTI%C3%93N_DE_BASES_DE_DATOS_RELACIONALES/tweets_extraction.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a>     tweet['fecha'] = datetime.strptime(tweet['fecha'], '%Y-%m-%dT%H:%M:%S.%fZ')
#       <a href='vscode-notebook-cell:/c%3A/Users/Natalia/Recursos%20DN_COM_58/DIGITAL-NAO-RETO_3-MySQL-SQL_SERVER_EN_LA_GESTI%C3%93N_DE_BASES_DE_DATOS_RELACIONALES/tweets_extraction.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a>     # Convertir retweets y favoritos de float a int
#       <a href='vscode-notebook-cell:/c%3A/Users/Natalia/Recursos%20DN_COM_58/DIGITAL-NAO-RETO_3-MySQL-SQL_SERVER_EN_LA_GESTI%C3%93N_DE_BASES_DE_DATOS_RELACIONALES/tweets_extraction.ipynb#X33sZmlsZQ%3D%3D?line=6'>7</a>     tweet['retweets'] = int(tweet['retweets'])
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
# Obtener un elemento representativo para análisis
primer_elemento = tweets_extraction[0] if isinstance(tweets_extraction, list) and tweets_extraction else tweets_extraction

# Función para explorar tipos de datos
def explore_data(tweets_extraction, path=''):
    if type(tweets_extraction) == dict:
        for key, value in tweets_extraction.items():
            explore_data(value, path + f'/{key}')
    elif type(tweets_extraction) == list:
        for i, item in enumerate(tweets_extraction):
            explore_data(item, path + f'[{i}]')
    else:
        print(f"{path}: {type(tweets_extraction)}")

# Llama a la función para explorar los tipos de datos usando el primer elemento
explore_data(primer_elemento)
# Out:
# /id: <class 'str'>
# /texto: <class 'str'>
# /usuario: <class 'str'>
# /hashtags[0]: <class 'str'>
# /hashtags[1]: <class 'str'>
# /fecha: <class 'datetime.datetime'>
# /retweets: <class 'int'>
# /favoritos: <class 'int'>

# %% [markdown]
# ## Etapa 4: Tratamiento de tweets y limpieza de datos

# %%
# Crear DataFrame
df = pd.DataFrame(tweets_extraction)
df
# Out:
#                        id                                              texto  \
# 0       12116719578733158  #BrechaAnuario2019 | Con cañón y coronel El vo...
# 1       12116547084876964  #BrechaAnuario2019 | Las PASO en Argentina "Em...
# 2       12116529643744993  #BrechaAnuario2019 | Bolsonaro contra la selva...
# 3       12110290516301292  #BrechaAnuario2019 | Aquí, los temas que apare...
# 4       12107119614801142  #BrechaAnuario2019 | El mejor dibujante de his...
# ...                   ...                                                ...
# 290601   1080102594054406  Felicidades en este  1 dia del 2019. A todos l...
# 290602  10800857075935356  Apareció flotando en una laguna el cuerpo del ...
# 290603   1080077600553427  Recluso de Santiago Vázquez no retornó de una ...
# 290604   1079905091438682  Volcán de Indonesia que desató el tsunami perd...
# 290605  10798902581903892  La economía mundial se frenará en 2019 https:/...
#
#                 usuario                                           hashtags  \
# 0       SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 1       SemanarioBrecha                                [BrechaAnuario2019]
# 2       SemanarioBrecha                                [BrechaAnuario2019]
# 3       SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 4       SemanarioBrecha                                [BrechaAnuario2019]
# ...                 ...                                                ...
# 290601   larepublica_uy                                                 []
# 290602   larepublica_uy                                                 []
# 290603   larepublica_uy                                                 []
# 290604   larepublica_uy                                                 []
# 290605   larepublica_uy                                                 []
#
#                      fecha  retweets  favoritos
# 0      2021-12-30 15:34:41         3          2
# 1      2021-12-30 14:26:08         2          1
# 2      2021-12-30 14:19:12         3          2
# 3      2021-12-28 21:00:00         2          5
# 4      2021-12-28 00:00:00         0          4
# ...                    ...       ...        ...
# 290601 2021-01-01 14:05:00        11         32
# 290602 2021-01-01 12:57:54         1          1
# 290603 2021-01-01 12:25:41         1          1
# 290604 2021-01-01 01:00:12         0          0
# 290605 2021-01-01 00:01:15         1          1
#
# [290606 rows x 7 columns]

# %%
# Revisar los tipos de datos en el DataFrame
print(df.dtypes)
# Out:
# id                   object
# texto                object
# usuario              object
# hashtags             object
# fecha        datetime64[ns]
# retweets              int64
# favoritos             int64
# dtype: object

# %%
# Crear nuevo DataFrame

# Calcular la cantidad de hashtags por tweet
df['cantidad_hastags'] = df['texto'].apply(lambda x: len(re.findall(r'#\w+', x)))

# Imprimir la cantidad máxima de hashtags
max_cantidad_hashtags = df['hashtags'].apply(lambda x: len(x)).max()
print(f"La cantidad máxima de hashtags en un tweet es: {max_cantidad_hashtags}")

# Mostrar el DataFrame con la nueva columna 'cantidad_hastags'
df
# Out:
# La cantidad máxima de hashtags en un tweet es: 11
#                        id                                              texto  \
# 0       12116719578733158  #BrechaAnuario2019 | Con cañón y coronel El vo...
# 1       12116547084876964  #BrechaAnuario2019 | Las PASO en Argentina "Em...
# 2       12116529643744993  #BrechaAnuario2019 | Bolsonaro contra la selva...
# 3       12110290516301292  #BrechaAnuario2019 | Aquí, los temas que apare...
# 4       12107119614801142  #BrechaAnuario2019 | El mejor dibujante de his...
# ...                   ...                                                ...
# 290601   1080102594054406  Felicidades en este  1 dia del 2019. A todos l...
# 290602  10800857075935356  Apareció flotando en una laguna el cuerpo del ...
# 290603   1080077600553427  Recluso de Santiago Vázquez no retornó de una ...
# 290604   1079905091438682  Volcán de Indonesia que desató el tsunami perd...
# 290605  10798902581903892  La economía mundial se frenará en 2019 https:/...
#
#                 usuario                                           hashtags  \
# 0       SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 1       SemanarioBrecha                                [BrechaAnuario2019]
# 2       SemanarioBrecha                                [BrechaAnuario2019]
# 3       SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 4       SemanarioBrecha                                [BrechaAnuario2019]
# ...                 ...                                                ...
# 290601   larepublica_uy                                                 []
# 290602   larepublica_uy                                                 []
# 290603   larepublica_uy                                                 []
# 290604   larepublica_uy                                                 []
# 290605   larepublica_uy                                                 []
#
#                      fecha  retweets  favoritos  cantidad_hastags
# 0      2021-12-30 15:34:41         3          2                 2
# 1      2021-12-30 14:26:08         2          1                 1
# 2      2021-12-30 14:19:12         3          2                 1
# 3      2021-12-28 21:00:00         2          5                 2
# 4      2021-12-28 00:00:00         0          4                 1
# ...                    ...       ...        ...               ...
# 290601 2021-01-01 14:05:00        11         32                 0
# 290602 2021-01-01 12:57:54         1          1                 0
# 290603 2021-01-01 12:25:41         1          1                 0
# 290604 2021-01-01 01:00:12         0          0                 0
# 290605 2021-01-01 00:01:15         1          1                 0
#
# [290606 rows x 8 columns]

# %%
# Revisar los tipos de datos en el DataFrame
print(df.dtypes)
# Out:
# id                          object
# texto                       object
# usuario                     object
# hashtags                    object
# fecha               datetime64[ns]
# retweets                     int64
# favoritos                    int64
# cantidad_hastags             int64
# dtype: object

# %% [markdown]
# ## Etapa 5: Verificar estructuras de los datos

# %%
df
# Out:
#                        id                                              texto  \
# 0       12116719578733158  #BrechaAnuario2019 | Con cañón y coronel El vo...
# 1       12116547084876964  #BrechaAnuario2019 | Las PASO en Argentina "Em...
# 2       12116529643744993  #BrechaAnuario2019 | Bolsonaro contra la selva...
# 3       12110290516301292  #BrechaAnuario2019 | Aquí, los temas que apare...
# 4       12107119614801142  #BrechaAnuario2019 | El mejor dibujante de his...
# ...                   ...                                                ...
# 290601   1080102594054406  Felicidades en este  1 dia del 2019. A todos l...
# 290602  10800857075935356  Apareció flotando en una laguna el cuerpo del ...
# 290603   1080077600553427  Recluso de Santiago Vázquez no retornó de una ...
# 290604   1079905091438682  Volcán de Indonesia que desató el tsunami perd...
# 290605  10798902581903892  La economía mundial se frenará en 2019 https:/...
#
#                 usuario                                           hashtags  \
# 0       SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 1       SemanarioBrecha                                [BrechaAnuario2019]
# 2       SemanarioBrecha                                [BrechaAnuario2019]
# 3       SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 4       SemanarioBrecha                                [BrechaAnuario2019]
# ...                 ...                                                ...
# 290601   larepublica_uy                                                 []
# 290602   larepublica_uy                                                 []
# 290603   larepublica_uy                                                 []
# 290604   larepublica_uy                                                 []
# 290605   larepublica_uy                                                 []
#
#                      fecha  retweets  favoritos  cantidad_hastags
# 0      2021-12-30 15:34:41         3          2                 2
# 1      2021-12-30 14:26:08         2          1                 1
# 2      2021-12-30 14:19:12         3          2                 1
# 3      2021-12-28 21:00:00         2          5                 2
# 4      2021-12-28 00:00:00         0          4                 1
# ...                    ...       ...        ...               ...
# 290601 2021-01-01 14:05:00        11         32                 0
# 290602 2021-01-01 12:57:54         1          1                 0
# 290603 2021-01-01 12:25:41         1          1                 0
# 290604 2021-01-01 01:00:12         0          0                 0
# 290605 2021-01-01 00:01:15         1          1                 0
#
# [290606 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290606 entries, 0 to 290605
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                290606 non-null  object
#  1   texto             290606 non-null  object
#  2   usuario           290606 non-null  object
#  3   hashtags          290606 non-null  object
#  4   fecha             290606 non-null  datetime64[ns]
#  5   retweets          290606 non-null  int64
#  6   favoritos         290606 non-null  int64
#  7   cantidad_hastags  290606 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 17.7+ MB

# %%
df.describe()
# Out:
#                                fecha       retweets      favoritos  \
# count                         290606  290606.000000  290606.000000
# mean   2022-04-10 20:03:50.898724864       5.228137      13.255759
# min              2021-01-01 00:00:01       0.000000       0.000000
# 25%              2021-09-07 11:06:15       0.000000       2.000000
# 50%              2022-04-30 23:26:53       2.000000       4.000000
# 75%       2022-11-13 12:14:07.500000       4.000000       9.000000
# max              2023-05-24 07:55:03    2600.000000    7200.000000
# std                              NaN      21.411017      55.577193
#
#        cantidad_hastags
# count     290606.000000
# mean           0.176012
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max           11.000000
# std            0.469430

# %%
df.head()
# Out:
#                   id                                              texto  \
# 0  12116719578733158  #BrechaAnuario2019 | Con cañón y coronel El vo...
# 1  12116547084876964  #BrechaAnuario2019 | Las PASO en Argentina "Em...
# 2  12116529643744993  #BrechaAnuario2019 | Bolsonaro contra la selva...
# 3  12110290516301292  #BrechaAnuario2019 | Aquí, los temas que apare...
# 4  12107119614801142  #BrechaAnuario2019 | El mejor dibujante de his...
#
#            usuario                                           hashtags  \
# 0  SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 1  SemanarioBrecha                                [BrechaAnuario2019]
# 2  SemanarioBrecha                                [BrechaAnuario2019]
# 3  SemanarioBrecha  [BrechaAnuario2019, RelecturasDeUnAñoPerturbador]
# 4  SemanarioBrecha                                [BrechaAnuario2019]
#
#                 fecha  retweets  favoritos  cantidad_hastags
# 0 2021-12-30 15:34:41         3          2                 2
# 1 2021-12-30 14:26:08         2          1                 1
# 2 2021-12-30 14:19:12         3          2                 1
# 3 2021-12-28 21:00:00         2          5                 2
# 4 2021-12-28 00:00:00         0          4                 1

# %%
# Guardar el DataFrame como un archivo CSV
df.to_csv('tweets_data.csv', index=False)

# %% [markdown]
# ## Etapa 6: Acerca del funcionamiento del código

# %% [markdown]
# **Importa librerías:**
#    - `pandas` para trabajar con DataFrames.
#    - `json` para manejar archivos JSON.
#    - `re` para operaciones con expresiones regulares.
#    - `datetime` para trabajar con fechas y horas.
#    - `Counter` para contar elementos en una lista.
#
# **Lee un archivo JSON:**
#    - Utiliza `json.load(file)` para cargar un archivo JSON llamado `tweets_extraction.json` que probablemente contiene datos de tweets.
#
# **Valida la estructura de los datos:**
#    - Verifica que cada tweet tenga ciertos campos como 'id', 'texto', 'usuario', 'hashtags', 'fecha', 'retweets', 'favoritos'. Utiliza un bucle `for` con `assert` para verificar esto.
#
# **Explora la estructura de los datos:**
#    - Define una función `explore_data` para explorar la estructura de los datos. Recorre los datos anidados (diccionarios y listas) para mostrar su estructura, tipo y ubicación en la jerarquía.
#
# **Convierte tipos de datos:**
#    - Modifica los tweets en `tweets_extraction` convirtiendo la cadena de fecha en formato `'%Y-%m-%dT%H:%M:%S.%fZ'` a objetos `datetime`. También convierte los campos 'retweets' y 'favoritos' de flotantes a enteros.
#
# **Crea un DataFrame:**
#    - Genera un DataFrame de Pandas con datos de ejemplo de tweets.
#
# **Cuenta la cantidad máxima de hashtags:**
#    - Utiliza expresiones regulares para encontrar y contar los hashtags en la columna 'texto' del DataFrame. Luego, encuentra la cantidad máxima de hashtags en un solo tweet y la imprime.
